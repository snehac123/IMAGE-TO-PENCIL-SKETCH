# %% [markdown]
# name - sneha chaplot
# task 2-image to pencil sketch using python

# %%
from google.colab.patches import cv2_imshow

# %%
import cv2

# %%
img = cv2.imread('tom-and-jerry.jpg', 1)

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=760x443 at 0x7F5B088D6790>

# %%
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
cv2_imshow(img_gray)
# Out:
# <PIL.Image.Image image mode=L size=760x443 at 0x7F5B077ADC10>

# %%
img_invert = cv2.bitwise_not(img_gray)

# %%
cv2_imshow(img_invert)
# Out:
# <PIL.Image.Image image mode=L size=760x443 at 0x7F5B077B6C50>

# %%
img_smoothing = cv2.GaussianBlur(img_invert, (21, 21),sigmaX=0, sigmaY=0)

# %%
cv2_imshow(img_smoothing)
# Out:
# <PIL.Image.Image image mode=L size=760x443 at 0x7F5B0881DB50>

# %%
def dodgeV2(x, y):
  return cv2.divide(x, 255 - y, scale=256)

# %%
final_img = dodgeV2(img_gray, img_smoothing)

# %%
cv2_imshow(final_img)
# Out:
# <PIL.Image.Image image mode=L size=760x443 at 0x7F5B077B66D0>
